# %% [markdown]
# ####**Import Libraries**

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ####**Import Dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b3815c72-83b7-432a-b6b8-1762b76d7313" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3815c72-83b7-432a-b6b8-1762b76d7313">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Weather Dataset.csv to Weather Dataset (2).csv

# %%
# Import dataset
data = pd.read_csv('Weather Dataset.csv')

# %%
data.head(5)
# Out:
#               Formatted Date  ... month
# 0  2006-03-31 22:00:00+00:00  ...     3
# 1  2006-03-31 23:00:00+00:00  ...     3
# 2  2006-04-01 00:00:00+00:00  ...     4
# 3  2006-04-01 01:00:00+00:00  ...     4
# 4  2006-04-01 02:00:00+00:00  ...     4
#
# [5 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            8760 non-null   object
#  1   Summary                   8760 non-null   object
#  2   Precip Type               8760 non-null   object
#  3   Temperature (C)           8760 non-null   float64
#  4   Apparent Temperature (C)  8760 non-null   float64
#  5   Humidity                  8760 non-null   float64
#  6   Wind Speed (km/h)         8760 non-null   float64
#  7   Wind Bearing (degrees)    8760 non-null   float64
#  8   Visibility (km)           8760 non-null   float64
#  9   Loud Cover                8760 non-null   float64
#  10  Pressure (millibars)      8760 non-null   float64
#  11  Daily Summary             8760 non-null   object
#  12  month                     8760 non-null   int64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 889.8+ KB

# %% [markdown]
# ####**Check Null Values**

# %%
data.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# month                       0
# dtype: int64

# %% [markdown]
# **No feature has any null values**

# %% [markdown]
# #### **Mean, Variance and Standard Deviation of Temperature (C)**

# %%
mean_temp = np.mean(data['Temperature (C)'])
print("Mean Temperature is :", mean_temp)
# Out:
# Mean Temperature is : 11.215224505327301

# %%
var_temp = np.var(data['Temperature (C)'])
print("Variation of Temperature is :", var_temp)
# Out:
# Variation of Temperature is : 92.10832938614995

# %%
standard_deviation_temp = np.std(data['Temperature (C)'])
print("Standard Deviation of Temperature is :", standard_deviation_temp)
# Out:
# Standard Deviation of Temperature is : 9.597308444879218

# %% [markdown]
# #### **Mean, Variance and Standard Deviation of Temperature (C) for every month**

# %%
for i in range(1, 13):
  month = data.loc[data["month"] == i]["Temperature (C)"]
  print("For month "+str(i))
  print("Mean temperature is "+ str(np.mean(month)))
  print("Standard deviation is "+ str(np.std(month))+"\n")
# Out:
# For month 1
# Mean temperature is -1.677942054958184
# Standard deviation is 4.571201837602936
#
# For month 2
# Mean temperature is -0.06539351851851898
# Standard deviation is 4.5619751209500565
#
# For month 3
# Mean temperature is 4.559274193548392
# Standard deviation is 5.716441576306105
#
# For month 4
# Mean temperature is 12.635030864197534
# Standard deviation is 4.770260724427961
#
# For month 5
# Mean temperature is 15.650731780167247
# Standard deviation is 4.74458172377508
#
# For month 6
# Mean temperature is 19.35462191358025
# Standard deviation is 6.647687763465947
#
# For month 7
# Mean temperature is 23.588664874551974
# Standard deviation is 5.348633953778178
#
# For month 8
# Mean temperature is 19.478726105137383
# Standard deviation is 4.751328709657937
#
# For month 9
# Mean temperature is 18.16773148148149
# Standard deviation is 4.81387851272809
#
# For month 10
# Mean temperature is 12.844758064516121
# Standard deviation is 5.97854812659291
#
# For month 11
# Mean temperature is 7.13770061728395
# Standard deviation is 4.32733696516641
#
# For month 12
# Mean temperature is 2.2182198327359615
# Standard deviation is 4.2767508050257605

# %% [markdown]
# **Conclusion -**
#
# - Here, April and May (month 4 and 5) look like a nice month to visit. The temperatures aren’t too high on average, and there isn’t a lot of variability.
#
# - The month with the lowest variability is December (month 12) with a standard deviation of 4.27.
